# %% [markdown]
# <a href="https://colab.research.google.com/github/NadiiaDataAnalyst/A-real-world-analytics-internship-with-CRM-sales-data-exported-from-the-Prog-Academy-system.-/blob/main/%D0%A1%D1%82%D0%B0%D0%B6%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B0_%D0%BE%D1%87%D0%B8%D1%89%D0%B5%D0%BD%D0%BD%D1%8F_%D0%B4%D0%B0%D0%BD%D0%B8%D1%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/crm_output_anonymized.csv'

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv(path,
                 sep=',',
                 quotechar='"',
                 encoding="utf-8-sig",
                 engine='python',
                 on_bad_lines='skip')
df
# Out:
#                                                      ID  \
# 0                    utm_source: meta;;;;;;;;;;;;;;;;;;
# 1                     utm_medium: cpc;;;;;;;;;;;;;;;;;;
# 2     utm_campaign: HTTP+|+Data+Analytics+++безкошто...
# 3     utm_content: broad+interests+–+27.05;;;;;;;;;;...
# 4                 utm_term: статика+6;;;;;;;;;;;;;;;;;;
# ...                                                 ...
# 5881      - Email: zfbirsutd137@gmail.com;;;;;;;;;;;...
# 5882                                           59320181
# 5883                                           59318911
# 5884                                 ;;;;;;;;;;;;;;;;;;
# 5885         але в нього зараз немає компа для навчання
#
#                              Lead title Lead sale ₴ Respons. user  \
# 0                                  None        None          None
# 1                                  None        None          None
# 2                                  None        None          None
# ...

# %%
df['ID'].unique()
# Out:
# array(['63408688,[NEW] free-data-analytics — /ua/free/data-analytics,0,Vasyl F.,04.06.2026 11:37:01,,04.06.2026 11:39:26,Ivan M.,not closed,,"\'=== First Touch ===;;;;;;;;;;;;;;;;;;',
#        'utm_source: meta;;;;;;;;;;;;;;;;;;',
#        'utm_medium: cpc;;;;;;;;;;;;;;;;;;', ...,
#        'але в нього зараз немає компа для навчання',
#        'нагадати про навчання на початку червня, має вирішити це питання",не встиг ще подивитись пробне,"веб дивився, але до цього проходив схожий в GOIT і для нього було скучно;;;;;;;;;;;;;;;;;;',
#        'для себе цікавився, відправив пробне, можливо зацікавить",,,Получил материалы,Продажи,Yulia Moroz,,Vasyl F.,,,,+380933183619,,,,,eiyoxxtsz458@outlook.com,,,,,,,,,,,No,,,,,,,,,Нет,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,https://ai-web-ua.prog.academy/,,,,,,,,;;;;;;;;;;;;;;;;;;'],
#       dtype=object)

# %%
print(df.columns.tolist())
# Out:
# ['ID', 'Lead title', 'Lead sale ₴', 'Respons. user', 'Created on', 'Created by', 'Modified on', 'Modified by', 'Closed at', 'Tags', 'Note', 'Note 2', 'Note 3', 'Note 4', 'Note 5', 'Lead stage', 'Pipeline', 'Fullname', 'Contact`s company', 'Contact respons. user', "Lead's company", 'Work phone', 'Work DD phone', 'Mobile phone', 'Fax', 'Home phone', 'Other phone', 'Work email', 'Personal email', 'Other email', 'Telegram', 'Position', 'Skype', 'ICQ', 'Jabber', 'Google Talk', 'MSN', 'Other IM', 'Facebook URL', 'Пользовательское соглашение', 'Title', 'TRAF_SRC', 'TRAF_TYPE', 'ADV_CAMP', 'KEYWORD', 'TRAF_CONT', 'GOOGLE_ID', 'Upcoming Appointment', 'Оплата', 'Курс', 'Lead scoring', 'Название пакета', 'Язык', 'Комментарий', 'COURSE', 'UTM_ID', 'UTM_ADGROUP', 'FORMNAME', 'URL первого визита', 'utm_source', 'utm_medium', 'utm_campaign', 'utm_term', 'utm_content', 'Referrer', 'ip', 'hostname', 'city', 'region', 'country', 'loc', 'org', 'day_of_week', 'TRAF_SRC.1', 'GOOGLE_ID.1', 'TRAF_CONT.1', 
# ...

# %%
print(df.isnull().sum())
# Out:
# ID                             0
# Lead title                  6984
# Lead sale ₴                 7027
# Respons. user               7040
# Created on                  7040
#                             ...
# utm_referrer                7208
# _ym_uid                     7221
# _ym_counter                 7221
# roistat                     7221
# ga_utm;;;;;;;;;;;;;;;;;;    7044
# Length: 109, dtype: int64

# %%
print(df.shape)
# Out:
# (7221, 109)

# %%
print(df.dtypes)
# Out:
# ID                           object
# Lead title                   object
# Lead sale ₴                  object
# Respons. user                object
# Created on                   object
#                              ...
# utm_referrer                 object
# _ym_uid                     float64
# _ym_counter                 float64
# roistat                     float64
# ga_utm;;;;;;;;;;;;;;;;;;     object
# Length: 109, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7221 entries, 0 to 7220
# Columns: 109 entries, ID to ga_utm;;;;;;;;;;;;;;;;;;
# dtypes: float64(49), object(60)
# memory usage: 6.0+ MB

# %%
df['Lead sale ₴'] = pd.to_numeric(df['Lead sale ₴'], errors='coerce')

# %%
df['Lead sale ₴'].sum()
# Out:
# np.float64(5000.0)

# %%
df_clean = df[pd.to_numeric(df['ID'], errors='coerce').notna()]
df_clean
# Out:
#             ID      Lead title  Lead sale ₴ Respons. user  \
# 44    63407150  Lead #63407150          0.0      Vasyl F.
# 575   63349437    380734324457          0.0     Oksana B.
# 615   63348663  Lead #63348663          0.0     Oksana B.
# 1226  63300203  Lead #63300203          0.0    Natalia H.
# 1712  63234121  Lead #63234121          0.0     Oksana B.
# ...        ...             ...          ...           ...
# 5864  59397093  Lead #59397093          0.0     Oksana B.
# 5868  59353455    380960149495          0.0    Natalia H.
# 5869  59353143  Lead #59353143          0.0     Oksana B.
# 5882  59320181  Lead #59320181          0.0      Vasyl F.
# 5883  59318911  Lead #59318911          0.0    Natalia H.
#
#                Created on Created by          Modified on Modified by  \
# 44    04.06.2026 09:29:40        NaN  04.06.2026 10:06:57    Vasyl F.
# 575   03.06.2026 12:33:46        NaN  03.06.2026 12:36:49   Oksana B.
# ...

# %%
df_clean['ID'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df_clean['Lead sale ₴'] = pd.to_numeric(df['Lead sale ₴'], errors='coerce')
# Out:
# /tmp/ipykernel_3245/2748740793.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Lead sale ₴'] = pd.to_numeric(df['Lead sale ₴'], errors='coerce')

# %%
df_clean['Lead sale ₴'] = df_clean['Lead sale ₴'].astype(float)
# Out:
# /tmp/ipykernel_3245/616112823.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Lead sale ₴'] = df_clean['Lead sale ₴'].astype(float)

# %%
print(df_clean['Respons. user'].unique())
# Out:
# ['Vasyl F.' 'Oksana B.' 'Natalia H.']

# %%
print(df_clean['Modified by'].unique())
# Out:
# ['Vasyl F.' 'Oksana B.' 'Natalia H.' 'Ivan M.' nan]

# %%
print(df_clean['Modified on'].unique())
# Out:
# ['04.06.2026 10:06:57' '03.06.2026 12:36:49' '03.06.2026 14:31:42'
#  '03.06.2026 13:55:08' '03.06.2026 16:55:37' '01.06.2026 10:02:30'
#  '03.06.2026 16:38:52' '01.06.2026 10:03:03' '01.06.2026 12:02:13'
#  '01.06.2026 12:02:54' '01.06.2026 16:04:54' '29.05.2026 10:49:58'
#  '30.05.2026 19:07:10' '29.05.2026 12:12:52' '31.05.2026 16:31:52'
#  '03.06.2026 16:57:00' '28.05.2026 15:14:42' '28.05.2026 15:17:39'
#  '28.05.2026 16:57:34' '01.06.2026 18:06:09' '03.06.2026 18:24:22'
#  '27.05.2026 13:36:21' '28.05.2026 12:53:02' '02.06.2026 11:27:21'
#  '25.05.2026 11:40:28' '25.05.2026 15:02:57' '25.05.2026 12:08:08'
#  '25.05.2026 12:20:35' '25.05.2026 12:23:20' '25.05.2026 12:24:28'
#  '25.05.2026 10:20:58' '28.05.2026 16:57:19' '22.05.2026 12:04:13'
#  '22.05.2026 11:54:01' '21.05.2026 18:17:29' '28.05.2026 19:09:44'
#  '21.05.2026 15:59:07' '22.05.2026 12:56:31' '26.05.2026 11:01:04'
#  '25.05.2026 17:10:47' '27.05.2026 18:39:14' '25.05.2026 16:46:47'
# ...

# %%
print(df_clean['utm_source'].unique())
# Out:
# [nan]

# %%
print(df_clean['utm_medium'].unique())
# Out:
# [nan]

# %%
print(df_clean['utm_campaign'].unique())
# Out:
# [nan]

# %%
print(df_clean['utm_term'].unique())
# Out:
# [nan]

# %%
print(df_clean['utm_content'].unique())
# Out:
# [nan]

# %%
columns_to_drop = ['utm_source', 'utm_medium', 'utm_campaign', 'utm_term', 'utm_content']

# %%
df_clean.drop(columns=columns_to_drop, inplace=True)
df_clean
# Out:
# /tmp/ipykernel_3327/3196811218.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean.drop(columns=columns_to_drop, inplace=True)
#             ID      Lead title  Lead sale ₴ Respons. user  \
# 44    63407150  Lead #63407150          0.0      Vasyl F.
# 575   63349437    380734324457          0.0     Oksana B.
# 615   63348663  Lead #63348663          0.0     Oksana B.
# 1226  63300203  Lead #63300203          0.0    Natalia H.
# 1712  63234121  Lead #63234121          0.0     Oksana B.
# ...        ...             ...          ...           ...
# 5864  59397093  Lead #59397093          0.0     Oksana B.
# 5868  59353455    380960149495          0.0    Natalia H.
# 5869  59353143  Lead #59353143          0.0     Oksana B.
# 5882  59320181  Lead #59320181          0.0      Vasyl F.
# ...

# %%
df_clean.rename(columns={
    'utm_source.1': 'utm_source',
    'utm_medium.1': 'utm_medium',
    'utm_campaign.1': 'utm_campaign',
    'utm_term.1': 'utm_term',
    'utm_content.1': 'utm_content'
}, inplace=True)
df_clean
# Out:
# /tmp/ipykernel_3327/787997786.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean.rename(columns={
#             ID      Lead title  Lead sale ₴ Respons. user  \
# 44    63407150  Lead #63407150          0.0      Vasyl F.
# 575   63349437    380734324457          0.0     Oksana B.
# 615   63348663  Lead #63348663          0.0     Oksana B.
# 1226  63300203  Lead #63300203          0.0    Natalia H.
# 1712  63234121  Lead #63234121          0.0     Oksana B.
# ...        ...             ...          ...           ...
# 5864  59397093  Lead #59397093          0.0     Oksana B.
# 5868  59353455    380960149495          0.0    Natalia H.
# 5869  59353143  Lead #59353143          0.0     Oksana B.
# 5882  59320181  Lead #59320181          0.0      Vasyl F.
# ...

# %%
df_clean['ga_utm;;;;;;;;;;;;;;;;;;'].unique()
# Out:
# array([';;;;;;;;;;;;;;;;;;', ';;', ';', ';;;;', nan, ';;;;;;', ';;;;;'],
#       dtype=object)

# %%
df_clean.drop(columns='ga_utm;;;;;;;;;;;;;;;;;;', inplace=True)
# Out:
# /tmp/ipykernel_3245/3303846724.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean.drop(columns='ga_utm;;;;;;;;;;;;;;;;;;', inplace=True)

# %%
df_clean_sale = df_clean[df_clean['Lead sale ₴']>0]
df_clean_sale
# Out:
#             ID      Lead title  Lead sale ₴ Respons. user  \
# 3856  62884053  Lead #62884053       5000.0     Oksana B.
#
#                Created on Created by          Modified on Modified by  \
# 3856  24.05.2026 12:42:07        NaN  25.05.2026 15:02:57     Ivan M.
#
#        Closed at       Tags                Note Note 2 Note 3 Note 4 Note 5  \
# 3856  not closed  da-online  в ведомость внесла    NaN    NaN    NaN    NaN
#
#               Lead stage Pipeline              Fullname Contact`s company  \
# 3856  Получили квитанцию  Продажи  Natalia Zakharchenko               NaN
#
#      Contact respons. user Lead's company      Work phone  Work DD phone  \
# 3856             Oksana B.            NaN  '+380631325326            NaN
#
#      Mobile phone  Fax  Home phone Other phone         Work email  \
# 3856          NaN  NaN         NaN         NaN  rxovdw760@ukr.net
#
#      Personal email Other email     Telegram  Position  Skype  ICQ  Jabber  \
# ...

# %%
df_clean['utm_campaign'].unique()
# Out:
# array([nan, 'pmax_ai_ua', 'Search - QA - EU', 'Search- Курс AI - UA',
#        'pmax_python_ua',
#        'HTTP | Data Analytics + безкоштовний курс | Site_Leads | TOF | 22.05',
#        'da_free_course_v2', 'pmax_python_eu', 'Search- Курс AI - EU',
#        'ai_auto_present', 'search_kursy_eu', 'search_kursy_ua', 'pmax_ua',
#        'test_1', 'pmax_eu', 'Search - DevOps - Ukraine',
#        'Search - Курс Data Analytics - Ukraine', 'qa_060426',
#        'da_free_course_v1', 'Search - Курс Data Analytics - EU'],
#       dtype=object)

# %%
df_clean['utm_term'].unique()
# Out:
# array([nan, 'обучение qa engineer с нуля', 'курсы по ии',
#        'курсы тестировщика', 'статика 3', 'курс по штучному інтелекту',
#        'n8n курс', 'курсы пайтон', 'курси пайтон', 'школа тестировщиков',
#        'devops курси', 'data science курс', 'devops engineer обучение',
#        'курс data engineer', 'тестировщик с нуля'], dtype=object)

# %%
df_clean['utm_medium'].unique()
# Out:
# array([nan, 'cpc', 'broadcast', 'channel', 'forum', 'bio'], dtype=object)

# %%
df_clean['utm_source'].unique()
# Out:
# array([nan, 'google', 'fb-insta', 'email', 'telegram', 'chatgpt.com',
#        'perplexity', 'dou', 'instagram'], dtype=object)

# %%
df_clean['utm_content'].unique()
# Out:
# array([nan, 'loc_interest_ms-__loc_physical_ms-9061060__device-m',
#        'loc_interest_ms-__loc_physical_ms-1030409__device-m',
#        'loc_interest_ms-__loc_physical_ms-1011430__device-m',
#        'broad interests',
#        'loc_interest_ms-__loc_physical_ms-9199197__device-m',
#        'loc_interest_ms-__loc_physical_ms-9044714__device-m',
#        '806220262713', '806220262710', '806220262692',
#        'loc_interest_ms-__loc_physical_ms-9067414__device-m',
#        'loc_interest_ms-__loc_physical_ms-9256967__device-m',
#        'loc_interest_ms-__loc_physical_ms-1012852__device-m',
#        'loc_interest_ms-__loc_physical_ms-9194283__device-m',
#        'loc_interest_ms-__loc_physical_ms-9197880__device-m',
#        'loc_interest_ms-__loc_physical_ms-9043353__device-m'],
#       dtype=object)

# %%
df_clean['utm_source'] = df_clean['utm_source'].fillna('not set')
df_clean
# Out:
# /tmp/ipykernel_3245/1395015279.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['utm_source'] = df_clean['utm_source'].fillna('not set')
#             ID      Lead title Lead sale ₴ Respons. user           Created on  \
# 44    63407150  Lead #63407150           0      Vasyl F.  04.06.2026 09:29:40
# 575   63349437    380734324457           0     Oksana B.  03.06.2026 12:33:46
# 615   63348663  Lead #63348663           0     Oksana B.  03.06.2026 11:40:29
# 1226  63300203  Lead #63300203           0    Natalia H.  02.06.2026 13:14:24
# 1712  63234121  Lead #63234121           0     Oksana B.  31.05.2026 16:10:06
# ...        ...             ...         ...           ...                  ...
# ...

# %%
df_clean['utm_content'] = df_clean['utm_content'].fillna('not set')
# Out:
# /tmp/ipykernel_3245/63685036.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['utm_content'] = df_clean['utm_content'].fillna('not set')

# %%
df_clean['utm_term'] = df_clean['utm_term'].fillna('not set')
# Out:
# /tmp/ipykernel_3245/760818835.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['utm_term'] = df_clean['utm_term'].fillna('not set')

# %%
df_clean['utm_medium'] = df_clean['utm_medium'].fillna('not set')
# Out:
# /tmp/ipykernel_3245/2177508337.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['utm_medium'] = df_clean['utm_medium'].fillna('not set')

# %%
df_clean['utm_source'] = df_clean['utm_source'].fillna('not set')
# Out:
# /tmp/ipykernel_3245/3379618113.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['utm_source'] = df_clean['utm_source'].fillna('not set')

# %%
df_clean['utm_campaign'] = df_clean['utm_campaign'].fillna('not set')
# Out:
# /tmp/ipykernel_3245/3191573807.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['utm_campaign'] = df_clean['utm_campaign'].fillna('not set')

# %%
df_clean['utm_source'] = df_clean['utm_source'].str.lower()
# Out:
# /tmp/ipykernel_3245/3432243357.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['utm_source'] = df_clean['utm_source'].str.lower()

# %%
df_clean['utm_source'] = df_clean['utm_source'].str.replace('fb-insta', 'facebook', case=False)
# Out:
# /tmp/ipykernel_3245/819471355.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['utm_source'] = df_clean['utm_source'].str.replace('fb-insta', 'facebook', case=False)

# %%
df_clean['Курс'].unique()
# Out:
# array([nan, 'QA-тестирование', 'Data Analytics - online', 'Java - очно',
#        'DevOps', 'AI Automation'], dtype=object)

# %%
df_clean['Modified on'] = pd.to_datetime(df_clean['Modified on'], dayfirst=True, errors='coerce')
# Out:
# /tmp/ipykernel_3245/2768511333.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Modified on'] = pd.to_datetime(df_clean['Modified on'], dayfirst=True, errors='coerce')

# %%
df_clean['Created on'] = pd.to_datetime(df_clean['Created on'], dayfirst=True, errors='coerce')
# Out:
# /tmp/ipykernel_3245/540604958.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Created on'] = pd.to_datetime(df_clean['Created on'], dayfirst=True, errors='coerce')

# %%
df_clean['Closed at'] = pd.to_datetime(df_clean['Closed at'], dayfirst=True, errors='coerce')
# Out:
# /tmp/ipykernel_3245/3805131007.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_clean['Closed at'] = pd.to_datetime(df_clean['Closed at'], dayfirst=True, errors='coerce')
# /tmp/ipykernel_3245/3805131007.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Closed at'] = pd.to_datetime(df_clean['Closed at'], dayfirst=True, errors='coerce')

# %%
df_clean['Year'] = df_clean['Created on'].dt.year
# Out:
# /tmp/ipykernel_3245/2990181063.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Year'] = df_clean['Created on'].dt.year

# %%
df_clean['Month number'] = df_clean['Created on'].dt.month
# Out:
# /tmp/ipykernel_3245/1841087623.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Month number'] = df_clean['Created on'].dt.month

# %%
df_clean['Month name'] = df_clean['Created on'].dt.month_name
# Out:
# /tmp/ipykernel_3245/1748961130.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Month name'] = df_clean['Created on'].dt.month_name

# %%
df_clean['Week Number'] = df_clean['Created on'].apply(lambda x: int(x.strftime('%W')) if pd.notna(x) else None)
# Out:
# /tmp/ipykernel_3245/799010172.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Week Number'] = df_clean['Created on'].apply(lambda x: int(x.strftime('%W')) if pd.notna(x) else None)

# %%
df_clean['Quarter'] = df_clean['Created on'].dt.quarter
# Out:
# /tmp/ipykernel_3245/1103178229.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Quarter'] = df_clean['Created on'].dt.quarter

# %%
df_clean.to_csv("crm_cleaned.csv", index=False, encoding="utf-8-sig")
